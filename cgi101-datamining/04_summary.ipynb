# %%
import pandas as pd

filePath = "./resource/holding.csv"

# %%
df = pd.read_csv(filePath)
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.head(10)
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 6  2998623  2020/11/30              7  2021/01/08         1.63   2194727.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
# 8  2998623  2020/11/30              9  2021/01/08         1.59   1403360.0
# 9  2998623  2020/11/30             10  2021/01/08         1.54   3065766.0
#
#      market_val                     security_name     cusip
# 0  3.103426e+08                 GENERAL MOTORS CO  37045V10
# ...

# %%
df.tail()
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878713     25000.0    22294.75
# 32878714     25000.0    21480.50
# 32878715     25000.0    21484.00
# 32878716     25000.0    19187.38
# 32878717     25000.0    14971.88
#
#                                           security_name     cusip
# 32878713     Bausch Health Companies Inc 5% 30-JAN-2028  071734AH
# 32878714  Bausch Health Companies Inc 5.25% 30-JAN-2030  071734AJ
# 32878715     Bausch Health Companies Inc 5% 15-FEB-2029  071734AM
# 32878716                        Endo DAC 6% 30-JUN-2028  29273DAC
# ...

# %%
df.tail(10)
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878708  3157350  2021/11/30            423  2021/12/21         0.12
# 32878709  3157350  2021/11/30            424  2021/12/21         0.12
# 32878710  3157350  2021/11/30            425  2021/12/21         0.12
# 32878711  3157350  2021/11/30            426  2021/12/21         0.11
# 32878712  3157350  2021/11/30            427  2021/12/21         0.11
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878708     25000.0    22810.50
# 32878709     25000.0    22726.50
# 32878710     25000.0    22700.00
# 32878711     25000.0    22685.13
# ...

# %%
df[500:600]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 500  2998821  2020/11/30              3  2021/01/08         2.74    585810.0
# 501  2998821  2020/11/30              4  2021/01/08         2.73   1019787.0
# 502  2998821  2020/11/30              5  2021/01/08         2.71   1645462.0
# 503  2998821  2020/11/30              6  2021/01/08         2.60    883918.0
# 504  2998821  2020/11/30              7  2021/01/08         2.57    988193.0
# ..       ...         ...            ...         ...          ...         ...
# 595  3000255  2020/11/30             41  2021/01/08         0.39     77958.0
# 596  3000255  2020/11/30             42  2021/01/08         0.32     40808.0
# 597  3000255  2020/11/30             43  2021/01/08         0.29    250000.0
# 598  3000255  2020/11/30             44  2021/01/08         0.25     20353.0
# 599  3000255  2020/11/30             45  2021/01/08         0.25     30575.0
#
# ...

# %%
df.loc[[1, 3, 5, 7], 'portno':'nbr_shares']
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0

# %%
df.iloc[[1, 3, 5, 7], 2:5]
# Out:
#    security_rank      eff_dt  percent_tna
# 1              2  2021/01/08         1.98
# 3              4  2021/01/08         1.75
# 5              6  2021/01/08         1.64
# 7              8  2021/01/08         1.60

# %%
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
df["portno"].dtype
# Out:
# dtype('O')

# %%
df.portno
# Out:
# 0           2998623
# 1           2998623
# 2           2998623
# 3           2998623
# 4           2998623
#              ...
# 32878713    3157350
# 32878714    3157350
# 32878715    3157350
# 32878716    3157350
# 32878717    3157350
# Name: portno, Length: 32878718, dtype: object

# %%
df["portno"].unique()
# Out:
# array(['2998623', '2998638', '2998809', ..., '3157332', '315733e',
#        '3157350'], dtype=object)

# %%
df["portno"].unique().__len__()
# Out:
# 11920

# %%
df["nbr_shares"].mean()
# Out:
# 41548315.25043799

# %%
# df["portno"].mean()

# %%
# df.mean()

# %%
df["portno"].value_counts()
# Out:
# 3066654    223027
# 3086928    185325
# 306841b    181445
# 3100110    127403
# 306920d    120721
#             ...
# 3092553         1
# 3069210         1
# 3065319         1
# 3077046         1
# 3078942         1
# Name: portno, Length: 11920, dtype: int64

# %%
'''
select portno, count(portno) from holding group by portno;
'''
# Out:
# '\nselect portno, count(portno) from holding group by portno;\n'

# %%
filter_3066654 = df["portno"] == '3066654'
filter_3066654
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32878713    False
# 32878714    False
# 32878715    False
# 32878716    False
# 32878717    False
# Name: portno, Length: 32878718, dtype: bool

# %%
df[filter_3066654]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 192449    3066654  2020/11/30           6311  2021/01/08         0.00
# 192450    3066654  2020/11/30           8263  2021/01/08         0.00
# 192451    3066654  2020/11/30          10658  2021/01/08         0.00
# 1751741   3066654  2020/12/31              2  2021/01/22         0.71
# 1751742   3066654  2020/12/31              4  2021/01/22         0.45
# ...           ...         ...            ...         ...          ...
# 31917974  3066654  2021/11/30          13747  2021/12/21         0.00
# 31917975  3066654  2021/11/30          13747  2021/12/21         0.00
# 31917976  3066654  2021/11/30          13747  2021/12/21         0.00
# 31917977  3066654  2021/11/30          13747  2021/12/21         0.00
# 31917978  3066654  2021/11/30          13747  2021/12/21         0.00
#
#             nbr_shares    market_val  \
# 192449    8.588000e+06  8.029780e+06
# 192450    5.025000e+06  5.094094e+06
# ...

# %%
filter_portno_3066654 = df["portno"] == '3066654'
filter_effdt_20210122 = df["eff_dt"] == '2021/01/22'

# %%
df[filter_portno_3066654 & filter_effdt_20210122]
# Out:
#           portno   report_dt  security_rank      eff_dt  percent_tna  \
# 1751741  3066654  2020/12/31              2  2021/01/22         0.71
# 1751742  3066654  2020/12/31              4  2021/01/22         0.45
# 1751743  3066654  2020/12/31              5  2021/01/22         0.43
# 1751744  3066654  2020/12/31              6  2021/01/22         0.42
# 1751745  3066654  2020/12/31              7  2021/01/22         0.40
# ...          ...         ...            ...         ...          ...
# 1763035  3066654  2020/12/31          13481  2021/01/22         0.00
# 1763036  3066654  2020/12/31          13481  2021/01/22         0.00
# 1763037  3066654  2020/12/31          13481  2021/01/22         0.00
# 1763038  3066654  2020/12/31          13481  2021/01/22         0.00
# 1763039  3066654  2020/12/31          13481  2021/01/22         0.00
#
#            nbr_shares    market_val  \
# 1751741  2.126420e+09  2.131736e+09
# 1751742  1.343651e+09  1.343651e+09
# ...

# %%
df[filter_portno_3066654 & filter_effdt_20210122].describe()
# Out:
#        security_rank   percent_tna    nbr_shares    market_val
# count   11299.000000  11299.000000  1.129900e+04  1.129900e+04
# mean     7030.397823      0.006570  2.001895e+07  2.220454e+07
# std      4208.051049      0.029295  8.223599e+07  8.745057e+07
# min         2.000000      0.000000  0.000000e+00  8.000000e-02
# 25%      3378.000000      0.000000  1.688541e+06  1.869749e+06
# 50%      6814.000000      0.000000  6.381000e+06  7.306780e+06
# 75%     10648.000000      0.010000  1.370250e+07  1.555783e+07
# max     13481.000000      0.710000  2.126420e+09  2.131736e+09

# %%
df.groupby("portno").size()
# Out:
# portno
# 2998623    4155
# 2998638     929
# 2998809     862
# 2998821     629
# 2998923     420
#            ...
# 315733b      16
# 315733e     363
# 3157347       5
# 315734a       3
# 3157350     428
# Length: 11920, dtype: int64

# %%
df.groupby(["portno", "eff_dt"]).size()
# Out:
# portno   eff_dt
# 2998623  2021/01/08    351
#          2021/02/05    349
#          2021/02/19      1
#          2021/03/08     86
#          2021/03/23    260
#                       ...
# 315733b  2021/12/07     16
# 315733e  2021/12/21    363
# 3157347  2021/12/07      5
# 315734a  2021/12/07      3
# 3157350  2021/12/21    428
# Length: 154098, dtype: int64

# %%
df.groupby(["portno", "eff_dt"]).sum()
# Out:
# /var/folders/bv/8bbkzq895db366kq27vw262r0000gn/T/ipykernel_47530/3739055544.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["portno", "eff_dt"]).sum()
#                     security_rank  percent_tna    nbr_shares    market_val
# portno  eff_dt
# 2998623 2021/01/08          61888        99.79  3.817768e+09  1.213476e+10
#         2021/02/05          61472        99.20  3.864276e+09  1.226047e+10
#         2021/02/19             72         0.56  3.054300e+07  6.951946e+07
#         2021/03/08           6384        70.69  9.649015e+08  8.516031e+09
#         2021/03/23          53751        29.08  2.971574e+09  3.517922e+09
# ...                           ...          ...           ...           ...
# 315733b 2021/12/07            137        99.73  1.783122e+07  2.601732e+07
# ...
