# %%
import pandas as pd

filename1 = "./resource/staff.csv"
filename2 = "./resource/staff_detail.csv"

# %%
df_staff = pd.read_csv(filename1)
df_detail = pd.read_csv(filename2)

# %%
df_staff
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
df_detail
# Out:
#     ID Level  UpdateDate
# 0    1     A  2019-08-09
# 1    1     S  2020-12-08
# 2    2     A  2021-05-30
# 3    3     A  2018-03-26
# 4    3     S  2020-12-08
# 5    4     A  2022-05-02
# 6    5     A  2019-11-05
# 7    5     S  2022-04-25
# 8    6     A  2022-03-03
# 9    7     A  2017-03-29
# 10   7     S  2018-05-02
# 11   7     M  2021-09-01
# 12   8     A  2018-11-26
# 13   8     S  2020-03-15
# 14   8     M  2022-05-03

# %%
df_staff.merge(df_detail)
# Out:
#     ID   Name  DeptId  Age Gender  Salary Level  UpdateDate
# 0    1   Mike       2   45      M   60000     A  2019-08-09
# 1    1   Mike       2   45      M   60000     S  2020-12-08
# 2    2   Judy       2   30      F   48000     A  2021-05-30
# 3    3  Allen       1   22      M   50000     A  2018-03-26
# 4    3  Allen       1   22      M   50000     S  2020-12-08
# 5    4    Tom       2   47      M   47000     A  2022-05-02
# 6    5   Jack       3   36      M   52000     A  2019-11-05
# 7    5   Jack       3   36      M   52000     S  2022-04-25
# 8    6   Abby       2   24      F   45000     A  2022-03-03
# 9    7  Trump       1   80      M   80000     A  2017-03-29
# 10   7  Trump       1   80      M   80000     S  2018-05-02
# 11   7  Trump       1   80      M   80000     M  2021-09-01
# 12   8  Marry       3   29      F   87000     A  2018-11-26
# 13   8  Marry       3   29      F   87000     S  2020-03-15
# 14   8  Marry       3   29      F   87000     M  2022-05-03

# %%
df_staff_detail_different_col = pd.read_csv("./resource/staff_detail_different_col.csv")
df_staff_detail_different_col
# Out:
#     EmpNum Level  UpdateDate
# 0        1     A  2019-08-09
# 1        1     S  2020-12-08
# 2        2     A  2021-05-30
# 3        3     A  2018-03-26
# 4        3     S  2020-12-08
# 5        4     A  2022-05-02
# 6        5     A  2019-11-05
# 7        5     S  2022-04-25
# 8        6     A  2022-03-03
# 9        7     A  2017-03-29
# 10       7     S  2018-05-02
# 11       7     M  2021-09-01
# 12       8     A  2018-11-26
# 13       8     S  2020-03-15
# 14       8     M  2022-05-03

# %%
df_staff.merge(df_staff_detail_different_col, left_on="ID", right_on="EmpNum")
# Out:
#     ID   Name  DeptId  Age Gender  Salary  EmpNum Level  UpdateDate
# 0    1   Mike       2   45      M   60000       1     A  2019-08-09
# 1    1   Mike       2   45      M   60000       1     S  2020-12-08
# 2    2   Judy       2   30      F   48000       2     A  2021-05-30
# 3    3  Allen       1   22      M   50000       3     A  2018-03-26
# 4    3  Allen       1   22      M   50000       3     S  2020-12-08
# 5    4    Tom       2   47      M   47000       4     A  2022-05-02
# 6    5   Jack       3   36      M   52000       5     A  2019-11-05
# 7    5   Jack       3   36      M   52000       5     S  2022-04-25
# 8    6   Abby       2   24      F   45000       6     A  2022-03-03
# 9    7  Trump       1   80      M   80000       7     A  2017-03-29
# 10   7  Trump       1   80      M   80000       7     S  2018-05-02
# 11   7  Trump       1   80      M   80000       7     M  2021-09-01
# 12   8  Marry       3   29      F   87000       8     A  2018-11-26
# ...

# %%
# !pip install pandasql
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/6b/c4/ee4096ffa2eeeca0c749b26f0371bd26aa5c8b611c43de99a4f86d3de0a7/pandasql-0.7.3.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/85/8a/83f1056449d819532c337a4a1b709a8e6291b9398340c0b2c00d5fdc7589/SQLAlchemy-1.4.41-cp38-cp38-macosx_10_15_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/5a/f1/db883c1526f167ee853ea1a7afcb21d77e0c62c84889cade85f57100eb60/greenlet-1.1.3-cp38-cp38-macosx_10_15_x86_64.whl
# ...
#   Running setup.py install for pandasql ... done
# ...

# %%
from pandasql import sqldf

# %%
df_staff
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
df_detail
# Out:
#     ID Level  UpdateDate
# 0    1     A  2019-08-09
# 1    1     S  2020-12-08
# 2    2     A  2021-05-30
# 3    3     A  2018-03-26
# 4    3     S  2020-12-08
# 5    4     A  2022-05-02
# 6    5     A  2019-11-05
# 7    5     S  2022-04-25
# 8    6     A  2022-03-03
# 9    7     A  2017-03-29
# 10   7     S  2018-05-02
# 11   7     M  2021-09-01
# 12   8     A  2018-11-26
# 13   8     S  2020-03-15
# 14   8     M  2022-05-03

# %%
sql = "select * from df_staff"

sqldf(sql, globals())
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
sql = "select ID, Name from df_staff"

sqldf(sql, globals())
# Out:
#    ID   Name
# 0   1   Mike
# 1   2   Judy
# 2   3  Allen
# 3   4    Tom
# 4   5   Jack
# 5   6   Abby
# 6   7  Trump
# 7   8  Marry

# %%
sql = """
    select * 
    from df_staff a
    left join df_detail b
    on a.ID=b.ID
"""

sqldf(sql, locals())
# Out:
#     ID   Name  DeptId  Age Gender  Salary  ID Level  UpdateDate
# 0    1   Mike       2   45      M   60000   1     A  2019-08-09
# 1    1   Mike       2   45      M   60000   1     S  2020-12-08
# 2    2   Judy       2   30      F   48000   2     A  2021-05-30
# 3    3  Allen       1   22      M   50000   3     A  2018-03-26
# 4    3  Allen       1   22      M   50000   3     S  2020-12-08
# 5    4    Tom       2   47      M   47000   4     A  2022-05-02
# 6    5   Jack       3   36      M   52000   5     A  2019-11-05
# 7    5   Jack       3   36      M   52000   5     S  2022-04-25
# 8    6   Abby       2   24      F   45000   6     A  2022-03-03
# 9    7  Trump       1   80      M   80000   7     A  2017-03-29
# 10   7  Trump       1   80      M   80000   7     M  2021-09-01
# 11   7  Trump       1   80      M   80000   7     S  2018-05-02
# 12   8  Marry       3   29      F   87000   8     A  2018-11-26
# 13   8  Marry       3   29      F   87000   8     M  2022-05-03
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\n\nfilename1 = "./resource/staff.csv"\nfilename2 = "./resource/staff_detail.csv"',
#   'df_staff = pd.read_csv(filename1)\ndf_detail = pd.read_csv(filename2)',
#   'df_staff',
#   'df_detail',
#   'df_staff.merge(df_detail)',
#   'df_staff_detail_different_col = pd.read_csv("staff_detail_different_col.csv")\ndf_staff_detail_different_col',
#   'df_staff_detail_different_col = pd.read_csv("./resource/staff_detail_different_col.csv")\ndf_staff_detail_different_col',
#   'df_staff.merge(df_staff_detail_different_col, left_on="ID", right_on="EmpNum")',
#   "get_ipython().system('pip install pandassql')",
#   "get_ipython().system('pip install pandasql')",
# ...

# %%
globals()["df_staff"]
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000
